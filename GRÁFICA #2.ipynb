# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv("FAOSTAT_data_es_9-21-2022.csv")
data
# Out:
#     Código Ámbito                Ámbito  Código área      Área  \
# 0              PP  Precios al Productor           95  Honduras
# 1              PP  Precios al Productor           95  Honduras
# 2              PP  Precios al Productor           95  Honduras
# 3              PP  Precios al Productor           95  Honduras
# 4              PP  Precios al Productor           95  Honduras
# ..            ...                   ...          ...       ...
# 305            PP  Precios al Productor           95  Honduras
# 306            PP  Precios al Productor           95  Honduras
# 307            PP  Precios al Productor           95  Honduras
# 308            PP  Precios al Productor           95  Honduras
# 309            PP  Precios al Productor           95  Honduras
#
#      Código Elemento                                          Elemento  \
# 0               5539  Índice de precios al productor (2014-2016 = 100)
# ...

# %%
data2 = pd.read_csv("FAOSTAT_data_es_9-21-2022.csv")
data2
# Out:
#     Código Ámbito                Ámbito  Código área      Área  \
# 0              PP  Precios al Productor           95  Honduras
# 1              PP  Precios al Productor           95  Honduras
# 2              PP  Precios al Productor           95  Honduras
# 3              PP  Precios al Productor           95  Honduras
# 4              PP  Precios al Productor           95  Honduras
# ..            ...                   ...          ...       ...
# 305            PP  Precios al Productor           95  Honduras
# 306            PP  Precios al Productor           95  Honduras
# 307            PP  Precios al Productor           95  Honduras
# 308            PP  Precios al Productor           95  Honduras
# 309            PP  Precios al Productor           95  Honduras
#
#      Código Elemento                                          Elemento  \
# 0               5539  Índice de precios al productor (2014-2016 = 100)
# ...

# %%
agricultura = data2[data2.Producto =="Agricultura"]
agricultura
# Out:
#    Código Ámbito                Ámbito  Código área      Área  \
# 0             PP  Precios al Productor           95  Honduras
# 1             PP  Precios al Productor           95  Honduras
# 2             PP  Precios al Productor           95  Honduras
# 3             PP  Precios al Productor           95  Honduras
# 4             PP  Precios al Productor           95  Honduras
# 5             PP  Precios al Productor           95  Honduras
# 6             PP  Precios al Productor           95  Honduras
# 7             PP  Precios al Productor           95  Honduras
# 8             PP  Precios al Productor           95  Honduras
# 9             PP  Precios al Productor           95  Honduras
# 10            PP  Precios al Productor           95  Honduras
# 11            PP  Precios al Productor           95  Honduras
# 12            PP  Precios al Productor           95  Honduras
# 13            PP  Precios al Productor           95  Honduras
# ...

# %%
ganado = data2[data2.Producto =="Ganado"]
ganado
# Out:
#     Código Ámbito                Ámbito  Código área      Área  \
# 124            PP  Precios al Productor           95  Honduras
# 125            PP  Precios al Productor           95  Honduras
# 126            PP  Precios al Productor           95  Honduras
# 127            PP  Precios al Productor           95  Honduras
# 128            PP  Precios al Productor           95  Honduras
# 129            PP  Precios al Productor           95  Honduras
# 130            PP  Precios al Productor           95  Honduras
# 131            PP  Precios al Productor           95  Honduras
# 132            PP  Precios al Productor           95  Honduras
# 133            PP  Precios al Productor           95  Honduras
# 134            PP  Precios al Productor           95  Honduras
# 135            PP  Precios al Productor           95  Honduras
# 136            PP  Precios al Productor           95  Honduras
# 137            PP  Precios al Productor           95  Honduras
# ...

# %%
data1 = data2.groupby(["Producto","Año"], sort=False)["Valor"].max()
data1.unstack().T.plot(kind="bar", subplots=False, layout=(2,2),figsize=(20,10), width=1)
# Out:
# <AxesSubplot:xlabel='Año'>
