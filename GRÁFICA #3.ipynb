# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data2 = pd.read_csv("FAOSTAT_data_es_9-21-2022.csv")
data2
ganado = data2[data2.Producto =="Ganado"]
ganado
data2 = ganado.groupby(["Producto","Año"], sort=False)["Valor"].max()
data2.unstack().T.plot(kind="bar", subplots=False, layout=(2,2),figsize=(20,10), width=1)
# Out:
# <AxesSubplot:xlabel='Año'>
